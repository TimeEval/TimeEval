# %% [markdown]
# # MIT-BIH Arrhythmia Database (_mitdb_)
#
# Part of the ECG Database Collection:
#
# | Short Name | Long Name |
# | :--- | :--- |
# | _mitdb_ | MIT-BIH Arrhythmia Database |
# | _svdb_ | MIT-BIH Supraventricular Arrhythmia Database |
# | _ltdb_ | MIT-BIH Long-Term ECG Database |
#
# [Docu](https://wfdb.readthedocs.io/en/latest) of the `wfdb`-package.

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import wfdb
import os
from typing import Final
from collections.abc import Callable
import matplotlib.pyplot as plt
from config import data_raw_folder, data_processed_folder
from IPython.display import display, Markdown, Latex

# %%
dataset_collection_name = "MITDB"
source_folder = os.path.join(data_raw_folder, "MIT-BIH Arrhythmia DB")
target_folder = data_processed_folder

# %% [markdown]
# Metadata handling

# %%
# type
DatasetMetadataRecord = {
    "dataset_name": str,
    "collection_name": str,
    "train_path": str,
    "test_path": str,
    "dataset_type": str,
    "datetime_index": bool,
    "split_at": int,
    "train_type": str,
    "train_is_normal": bool,
    "input_type": str,
    "length": int
}

class DatasetMetadata:
    """
    ATTENTION: Not thread-safe! There is no check for changes to the underlying `dataset.csv` file while this class is loaded.
    """
    
    FILENAME: Final[str] = "datasets.csv"
    
    _filepath: str
    _df: pd.DataFrame
    _dirty: bool

    def __init__(self, target_folder: str):
        self._filepath = os.path.join(target_folder, self.FILENAME)
        self._dirty = False
        if not os.path.isfile(self._filepath):
            self._df = self._create_metadata_file()
        else:
            self.refresh(force = True)
    
    def __enter__(self) -> 'DatasetMetadata':
        return self
    
    def __exit__(self, exception_type, exception_value, exception_traceback) -> 'DatasetMetadata':
        self.save()
        return self
    
    def __repr__(self) -> str:
        return repr(self._df)
    
    def __str__(self) -> str:
        return str(self._df)
        
    def _create_metadata_file(self) -> pd.DataFrame:
        df_temp = pd.DataFrame(columns=["dataset_name", "collection_name", "train_path", "test_path", "type", "datetime_index", "split_at", "train_type", "train_is_normal", "input_type", "length"])
        df_temp.set_index(["dataset_name", "collection_name"], inplace=True)
        df_temp.to_csv(self._filepath)
        return df_temp
    
    def add_dataset(self,
        dataset_name: str,
        collection_name: str,
        train_path: str,
        test_path: str,
        dataset_type: str,
        datetime_index: bool,
        split_at: int,
        train_type: str,
        train_is_normal: bool,
        input_type: str,
        dataset_length: int
    ) -> 'DatasetMetadata':
        df_new = pd.DataFrame({
            "train_path": train_path,
            "test_path": test_path,
            "type": dataset_type,
            "datetime_index": datetime_index,
            "split_at": split_at,
            "train_type": train_type,
            "train_is_normal": train_is_normal,
            "input_type": input_type,
            "length": dataset_length
        }, index=[(dataset_name, dataset_collection_name)])
        df = pd.concat([self._df, df_new], axis=0)
        df = df[~df.index.duplicated(keep = "last")]
        self._df = df
        self._dirty = True
        return self
    
    def add_datasets(self, datasets: list[DatasetMetadataRecord]) -> 'DatasetMetadata':
        df_new = pd.DataFrame(datasets)
        df_new.set_index(["dataset_name", "collection_name"], inplace = True)
        df = pd.concat([self._df, df_new], axis=0)
        df = df[~df.index.duplicated(keep = "last")]
        self._df = df
        self._dirty = True
        return self
    
    def refresh(self, force: bool = False) -> None:
        if not force and self._dirty:
            raise Exception("There are unsaved changes in memory that would get lost by reading from disk again!")
        else:
            self._df = pd.read_csv(self._filepath, index_col=["dataset_name", "collection_name"])
    
    def save(self) -> None:
        self._df.to_csv(self._filepath)
        self._dirty = False

# %%
def load_dataset_names() -> list[str]:
    with open(os.path.join(source_folder, "RECORDS"), 'r') as f:
        records = [l.rstrip('\n') for l in f]
    return records

# %%
ann_normal = ["N", "/", "L", "R"]
ann_beat = ["F", "f", "S", "A", "a", "V", "J", "j", "E", "e"]
ann_no_beat = ["x"]
ann_fibr_start = "["
ann_fibr_end = "]"
ann_fibr = [ann_fibr_start, "!", ann_fibr_end]
ann_ext = ["Q", "|"]
ann_ignore = ["+", "~", '"']

def transform_and_label(source_file: str, target: str) -> int:
    print(f"Transforming {os.path.basename(source_file)}")
    # load dataset
    record = wfdb.rdrecord(source_file)
    df_record = pd.DataFrame(record.p_signal, columns=record.sig_name)
    print(f"  record {record.file_name[0]} loaded")

    # load annotation file
    atr = wfdb.rdann(source_file, "atr")
    assert record.fs == atr.fs, "Sample frequency of records and annotations does not match!"
    df_annotation = pd.DataFrame({"position": atr.sample, "label": atr.symbol})
    # remove ignored annotations
    df_annotation = df_annotation[~df_annotation["label"].isin(ann_ignore)]
    df_annotation = df_annotation.reset_index(drop=True)
    print(f"  {len(df_annotation)}/{atr.ann_len} beat annotations for {source_file} loaded (others were ignored)")

    # calculate normal beat length
    print("  preparing windows for labeling...")
    df_normal_beat = df_annotation.copy()
    df_normal_beat["prev_position"] = df_annotation["position"].shift()
    df_normal_beat["prev_label"] = df_annotation["label"].shift()
    df_normal_beat = df_normal_beat[(df_normal_beat["label"].isin(ann_normal)) & (df_normal_beat["prev_label"].isin(ann_normal))]
    df_normal_beat = df_normal_beat.drop(columns=["label", "prev_label"])
    s_normal_beat_lengths = df_normal_beat["position"] - df_normal_beat["prev_position"]
    print(f"    normal beat distance samples = {len(s_normal_beat_lengths)}")
    normal_beat_length = s_normal_beat_lengths.median()
    if (normal_beat_length % 2) == 0:
        normal_beat_length += 1
    beat_window_size = int(normal_beat_length)
    beat_window_margin = (beat_window_size - 1)//2
    del df_normal_beat
    del s_normal_beat_lengths
    print(f"    window size = {beat_window_size}")
    print(f"    window margins (left and right) = {beat_window_margin}")

    # calculate beat windows
    ## ~ and other annotations are ignored!
    ## for fibrillation
    # we only need start and end marked with `[` and `]` respectively
    s_fibr_start = df_annotation.loc[df_annotation["label"] == ann_fibr_start, "position"]
    s_index = s_fibr_start.index
    s_fibr_start = s_fibr_start.reset_index(drop=True)
    s_fibr_end = df_annotation.loc[df_annotation["label"] == ann_fibr_end, "position"]
    s_fibr_end = s_fibr_end.reset_index(drop=True)
    df_fibr = pd.DataFrame({"index": s_index, "window_start": s_fibr_start, "window_end": s_fibr_end})
    df_fibr = df_fibr.set_index("index")
    df_fibr["position"] = df_fibr["window_start"]
    print(f"    {len(df_fibr)} windows for fibrillation anomalies ({','.join(ann_fibr)})")
    ## for external anomalies
    df_ext = df_annotation[df_annotation["label"].isin(ann_ext)].copy()
    df_ext["window_start"] = np.maximum(0, df_ext["position"]-beat_window_margin)
    df_ext["window_end"] = np.minimum(record.sig_len - 1, df_ext["position"]+beat_window_margin)
    df_ext = df_ext[["position", "window_start", "window_end"]]
    print(f"    {len(df_ext)} windows for external anomalies ({','.join(ann_ext)})")
    ## anomalous beats
    # exclude additional non-beat annotations
    df_svf = df_annotation[~df_annotation["label"].isin(["|", ann_fibr_start, ann_fibr_end])].copy()
    df_svf["position_next"] = df_svf["position"].shift(-1)
    df_svf["position_prev"] = df_svf["position"].shift(1)
    #df_svf = df_svf[(df_svf["position_prev"].notnull()) & (df_svf["position_next"].notnull())]
    df_svf = df_svf[df_svf["label"].isin(ann_beat)]
    df_svf["window_start"] = np.maximum(0, np.minimum(df_svf["position"].values-beat_window_margin, df_svf["position_prev"].values+beat_window_margin))
    df_svf["window_end"] = np.minimum(record.sig_len - 1, np.maximum(df_svf["position"].values+beat_window_margin, df_svf["position_next"].values-beat_window_margin))
    df_svf = df_svf[["position", "window_start", "window_end"]]
    print(f"    {len(df_svf)} windows for anomalous beats ({','.join(ann_beat)})")
    # missing beats
    df_no_beat = df_annotation[df_annotation["label"].isin(ann_no_beat)].drop(columns=["label"]).copy()
    df_no_beat["window_start"] = df_no_beat["position"]
    if not df_no_beat.empty:
        df_normal_windows = df_annotation[df_annotation["label"].isin(ann_normal)].copy()
        df_normal_windows = df_normal_windows.drop(columns=["label"])
        df_normal_windows["window_start"] = np.maximum(0, df_normal_windows["position"]-beat_window_margin)
        df_normal_windows["window_end"] = np.minimum(record.sig_len - 1, df_normal_windows["position"]+beat_window_margin)
        df_lut = df_annotation[~df_annotation["label"].isin(ann_no_beat)].merge(pd.concat([df_ext, df_svf, df_fibr, df_normal_windows]), on="position", how="left")
        def find_next_window_start(pos: int):
            next_window_start = df_lut.loc[df_lut["position"] > pos, "window_start"].iloc[0]
            return max(pos, next_window_start)
        df_no_beat["window_end"] = df_no_beat["position"].transform(find_next_window_start)
        del df_normal_windows
        del df_lut
    else:
        df_no_beat["window_end"] = df_no_beat["position"]
    print(f"    {len(df_no_beat)} windows for missing beats ({','.join(ann_no_beat)})")
    ## merge
    df_windows = pd.concat([df_ext, df_svf, df_fibr, df_no_beat])
    df_windows.sort_index(inplace=True)
    print(f"  ...done.")

    # add labels based on anomaly windows
    print("  labeling")
    df_record["is_anomaly"] = 0
    for _, (_, t1, t2) in df_windows.iterrows():
        tmp = df_record[df_record.index >= t1]
        tmp = tmp[tmp.index <= t2]
        df_record["is_anomaly"].values[tmp.index] = 1
    del tmp

    # reconstruct timestamps and set as index
    print("  reconstructing timestamps")
    df_record["timestamp"] = pd.to_datetime(df_record.index.values * 1e+9/record.fs, unit='ns')
    df_record = df_record.set_index("timestamp")
    df_record.to_csv(target)
    print(f"Dataset {os.path.basename(source_file)} transformed and saved!")
    
    # return dataset length
    return record.sig_len

# %%
# shared by all datasets
dataset_type = "real"
input_type = "multivariate"
datetime_index = True
train_type = "unsupervised"
train_is_normal = False

dm = DatasetMetadata(target_folder)

# create target directory
dataset_subfolder = os.path.join(target_folder, input_type, dataset_collection_name)
try:
    os.makedirs(dataset_subfolder)
    print(f"Created directories {dataset_subfolder}")
except FileExistsError:
    print(f"Directories {dataset_subfolder} already exist")
    pass
# Out:
# Directories data-processed/multivariate/MITDB already exist

# %%
# dataset transformation
transform_file: Callable[[str, str], int] = transform_and_label

for dataset_name in load_dataset_names():
    # intentionally no file suffix (.dat)
    source_file = os.path.join(source_folder, dataset_name)
    filename = f"{dataset_name}.test.csv"
    path = os.path.join(dataset_subfolder, filename)
            
    # transform file and label it
    dataset_length = transform_file(source_file, path)
    print(f"Processed source dataset {source_file} -> {path}")

    # save metadata
    dm.add_dataset(
        dataset_name = dataset_name,
        collection_name = dataset_collection_name,
        train_path = None,
        test_path = path,
        dataset_type = dataset_type,
        datetime_index = datetime_index,
        split_at = None,
        train_type = train_type,
        train_is_normal = train_is_normal,
        input_type = input_type,
        dataset_length = dataset_length
    )

# save metadata of benchmark
dm.save()
# Out:
# Transforming 100
#   record 100.dat loaded
#   2273/2274 beat annotations for data-raw/MIT-BIH Arrhythmia DB/100 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2204
#     window size = 287
#     window margins (left and right) = 143
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     34 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 100 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/100 -> data-processed/multivariate/MITDB/100.test.csv
# Transforming 101
#   record 101.dat loaded
#   1869/1874 beat annotations for data-raw/MIT-BIH Arrhythmia DB/101 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1851
#     window size = 353
#     window margins (left and right) = 176
#     0 windows for fibrillation anomalies ([,!,])
#     6 windows for external anomalies (Q,|)
#     3 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 101 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/101 -> data-processed/multivariate/MITDB/101.test.csv
# Transforming 102
#   record 102.dat loaded
#   2187/2192 beat annotations for data-raw/MIT-BIH Arrhythmia DB/102 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2099
#     window size = 297
#     window margins (left and right) = 148
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     60 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 102 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/102 -> data-processed/multivariate/MITDB/102.test.csv
# Transforming 103
#   record 103.dat loaded
#   2084/2091 beat annotations for data-raw/MIT-BIH Arrhythmia DB/103 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2079
#     window size = 313
#     window margins (left and right) = 156
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     2 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 103 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/103 -> data-processed/multivariate/MITDB/103.test.csv
# Transforming 104
#   record 104.dat loaded
#   2229/2311 beat annotations for data-raw/MIT-BIH Arrhythmia DB/104 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1324
#     window size = 291
#     window margins (left and right) = 145
#     0 windows for fibrillation anomalies ([,!,])
#     18 windows for external anomalies (Q,|)
#     668 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 104 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/104 -> data-processed/multivariate/MITDB/104.test.csv
# Transforming 105
#   record 105.dat loaded
#   2602/2691 beat annotations for data-raw/MIT-BIH Arrhythmia DB/105 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2450
#     window size = 253
#     window margins (left and right) = 126
#     0 windows for fibrillation anomalies ([,!,])
#     35 windows for external anomalies (Q,|)
#     41 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 105 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/105 -> data-processed/multivariate/MITDB/105.test.csv
# Transforming 106
#   record 106.dat loaded
#   2027/2098 beat annotations for data-raw/MIT-BIH Arrhythmia DB/106 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1083
#     window size = 345
#     window margins (left and right) = 172
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     520 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 106 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/106 -> data-processed/multivariate/MITDB/106.test.csv
# Transforming 107
#   record 107.dat loaded
#   2137/2140 beat annotations for data-raw/MIT-BIH Arrhythmia DB/107 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2018
#     window size = 307
#     window margins (left and right) = 153
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     59 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 107 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/107 -> data-processed/multivariate/MITDB/107.test.csv
# Transforming 108
#   record 108.dat loaded
#   1782/1824 beat annotations for data-raw/MIT-BIH Arrhythmia DB/108 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1708
#     window size = 371
#     window margins (left and right) = 185
#     0 windows for fibrillation anomalies ([,!,])
#     8 windows for external anomalies (Q,|)
#     24 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
# enter 4197
# for pos 4197 val 4417.0
# enter 11000
# for pos 11000 val 11268.0
# enter 180184
# for pos 180184 val 180369.0
# enter 193696
# for pos 193696 val 193948.0
# enter 221307
# for pos 221307 val 221553.0
# enter 326699
# for pos 326699 val 326976.0
# enter 393120
# for pos 393120 val 393336.0
# enter 490898
# for pos 490898 val 491153.0
# enter 526532
# for pos 526532 val 526768.0
# enter 580872
# for pos 580872 val 581127.0
# enter 619299
# for pos 619299 val 619458.0
#     11 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 108 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/108 -> data-processed/multivariate/MITDB/108.test.csv
# Transforming 109
#   record 109.dat loaded
#   2532/2535 beat annotations for data-raw/MIT-BIH Arrhythmia DB/109 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2451
#     window size = 257
#     window margins (left and right) = 128
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     40 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 109 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/109 -> data-processed/multivariate/MITDB/109.test.csv
# Transforming 111
#   record 111.dat loaded
#   2124/2133 beat annotations for data-raw/MIT-BIH Arrhythmia DB/111 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2121
#     window size = 307
#     window margins (left and right) = 153
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     1 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 111 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/111 -> data-processed/multivariate/MITDB/111.test.csv
# Transforming 112
#   record 112.dat loaded
#   2539/2550 beat annotations for data-raw/MIT-BIH Arrhythmia DB/112 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2534
#     window size = 257
#     window margins (left and right) = 128
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     2 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 112 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/112 -> data-processed/multivariate/MITDB/112.test.csv
# Transforming 113
#   record 113.dat loaded
#   1795/1796 beat annotations for data-raw/MIT-BIH Arrhythmia DB/113 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1782
#     window size = 365
#     window margins (left and right) = 182
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     6 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 113 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/113 -> data-processed/multivariate/MITDB/113.test.csv
# Transforming 114
#   record 114.dat loaded
#   1880/1890 beat annotations for data-raw/MIT-BIH Arrhythmia DB/114 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1767
#     window size = 341
#     window margins (left and right) = 170
#     0 windows for fibrillation anomalies ([,!,])
#     1 windows for external anomalies (Q,|)
#     59 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 114 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/114 -> data-processed/multivariate/MITDB/114.test.csv
# Transforming 115
#   record 115.dat loaded
#   1959/1962 beat annotations for data-raw/MIT-BIH Arrhythmia DB/115 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1947
#     window size = 329
#     window margins (left and right) = 164
#     0 windows for fibrillation anomalies ([,!,])
#     6 windows for external anomalies (Q,|)
#     0 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 115 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/115 -> data-processed/multivariate/MITDB/115.test.csv
# Transforming 116
#   record 116.dat loaded
#   2412/2421 beat annotations for data-raw/MIT-BIH Arrhythmia DB/116 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2193
#     window size = 269
#     window margins (left and right) = 134
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     110 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 116 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/116 -> data-processed/multivariate/MITDB/116.test.csv
# Transforming 117
#   record 117.dat loaded
#   1535/1539 beat annotations for data-raw/MIT-BIH Arrhythmia DB/117 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1532
#     window size = 425
#     window margins (left and right) = 212
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     1 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 117 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/117 -> data-processed/multivariate/MITDB/117.test.csv
# Transforming 118
#   record 118.dat loaded
#   2288/2301 beat annotations for data-raw/MIT-BIH Arrhythmia DB/118 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2047
#     window size = 291
#     window margins (left and right) = 145
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     112 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
# enter 64520
# for pos 64520 val 64809.0
# enter 68923
# for pos 68923 val 69230.0
# enter 103214
# for pos 103214 val 103524.0
# enter 299687
# for pos 299687 val 300000.0
# enter 310750
# for pos 310750 val 311006.0
# enter 366178
# for pos 366178 val 366489.0
# enter 379138
# for pos 379138 val 379431.0
# enter 409570
# for pos 409570 val 409877.0
# enter 479884
# for pos 479884 val 480222.0
# enter 489105
# for pos 489105 val 489105
#     10 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 118 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/118 -> data-processed/multivariate/MITDB/118.test.csv
# Transforming 119
#   record 119.dat loaded
#   1987/2094 beat annotations for data-raw/MIT-BIH Arrhythmia DB/119 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1098
#     window size = 325
#     window margins (left and right) = 162
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     444 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 119 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/119 -> data-processed/multivariate/MITDB/119.test.csv
# Transforming 121
#   record 121.dat loaded
#   1863/1876 beat annotations for data-raw/MIT-BIH Arrhythmia DB/121 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1858
#     window size = 359
#     window margins (left and right) = 179
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     2 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 121 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/121 -> data-processed/multivariate/MITDB/121.test.csv
# Transforming 122
#   record 122.dat loaded
#   2478/2479 beat annotations for data-raw/MIT-BIH Arrhythmia DB/122 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2473
#     window size = 263
#     window margins (left and right) = 131
#     0 windows for fibrillation anomalies ([,!,])
#     2 windows for external anomalies (Q,|)
#     0 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 122 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/122 -> data-processed/multivariate/MITDB/122.test.csv
# Transforming 123
#   record 123.dat loaded
#   1518/1519 beat annotations for data-raw/MIT-BIH Arrhythmia DB/123 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1511
#     window size = 433
#     window margins (left and right) = 216
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     3 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 123 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/123 -> data-processed/multivariate/MITDB/123.test.csv
# Transforming 124
#   record 124.dat loaded
#   1619/1634 beat annotations for data-raw/MIT-BIH Arrhythmia DB/124 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1509
#     window size = 405
#     window margins (left and right) = 202
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     88 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 124 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/124 -> data-processed/multivariate/MITDB/124.test.csv
# Transforming 200
#   record 200.dat loaded
#   2601/2792 beat annotations for data-raw/MIT-BIH Arrhythmia DB/200 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 945
#     window size = 243
#     window margins (left and right) = 121
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     858 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 200 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/200 -> data-processed/multivariate/MITDB/200.test.csv
# Transforming 201
#   record 201.dat loaded
#   2000/2039 beat annotations for data-raw/MIT-BIH Arrhythmia DB/201 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1295
#     window size = 267
#     window margins (left and right) = 133
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     338 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
# enter 159364
# for pos 159364 val 159818.0
# enter 160024
# for pos 160024 val 160476.0
# enter 160693
# for pos 160693 val 161158.0
# enter 165235
# for pos 165235 val 165368.0
# enter 166407
# for pos 166407 val 166842.0
# enter 190075
# for pos 190075 val 190536.0
# enter 190744
# for pos 190744 val 191237.0
# enter 191455
# for pos 191455 val 191933.0
# enter 192138
# for pos 192138 val 192583.0
# enter 192789
# for pos 192789 val 193269.0
# enter 193490
# for pos 193490 val 193959.0
# enter 194173
# for pos 194173 val 194608.0
# enter 194810
# for pos 194810 val 195288.0
# enter 195503
# for pos 195503 val 196004.0
# enter 196227
# for pos 196227 val 196668.0
# enter 198452
# for pos 198452 val 198901.0
# enter 462156
# for pos 462156 val 462588.0
# enter 527903
# for pos 527903 val 528417.0
# enter 530053
# for pos 530053 val 530562.0
# enter 532956
# for pos 532956 val 533421.0
# enter 536473
# for pos 536473 val 537001.0
# enter 539386
# for pos 539386 val 539868.0
# enter 543793
# for pos 543793 val 544268.0
# enter 546687
# for pos 546687 val 547162.0
# enter 548833
# for pos 548833 val 548920.0
# enter 551796
# for pos 551796 val 552310.0
# enter 551907
# for pos 551907 val 552310.0
# enter 560815
# for pos 560815 val 561300.0
# enter 564913
# for pos 564913 val 565046.0
# enter 566349
# for pos 566349 val 566851.0
# enter 567803
# for pos 567803 val 568263.0
# enter 568486
# for pos 568486 val 568961.0
# enter 569921
# for pos 569921 val 570360.0
# enter 571684
# for pos 571684 val 571790.0
# enter 573143
# for pos 573143 val 573668.0
# enter 647321
# for pos 647321 val 647832.0
# enter 649181
# for pos 649181 val 649667.0
#     37 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 201 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/201 -> data-processed/multivariate/MITDB/201.test.csv
# Transforming 202
#   record 202.dat loaded
#   2138/2146 beat annotations for data-raw/MIT-BIH Arrhythmia DB/202 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2001
#     window size = 323
#     window margins (left and right) = 161
#     0 windows for fibrillation anomalies ([,!,])
#     2 windows for external anomalies (Q,|)
#     75 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 202 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/202 -> data-processed/multivariate/MITDB/202.test.csv
# Transforming 203
#   record 203.dat loaded
#   3006/3108 beat annotations for data-raw/MIT-BIH Arrhythmia DB/203 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2184
#     window size = 233
#     window margins (left and right) = 116
#     0 windows for fibrillation anomalies ([,!,])
#     30 windows for external anomalies (Q,|)
#     447 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 203 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/203 -> data-processed/multivariate/MITDB/203.test.csv
# Transforming 205
#   record 205.dat loaded
#   2657/2672 beat annotations for data-raw/MIT-BIH Arrhythmia DB/205 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2528
#     window size = 243
#     window margins (left and right) = 121
#     0 windows for fibrillation anomalies ([,!,])
#     1 windows for external anomalies (Q,|)
#     85 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 205 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/205 -> data-processed/multivariate/MITDB/205.test.csv
# Transforming 207
#   record 207.dat loaded
#   2346/2385 beat annotations for data-raw/MIT-BIH Arrhythmia DB/207 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1438
#     window size = 337
#     window margins (left and right) = 168
#     6 windows for fibrillation anomalies ([,!,])
#     2 windows for external anomalies (Q,|)
#     317 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 207 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/207 -> data-processed/multivariate/MITDB/207.test.csv
# Transforming 208
#   record 208.dat loaded
#   2963/3040 beat annotations for data-raw/MIT-BIH Arrhythmia DB/208 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 689
#     window size = 209
#     window margins (left and right) = 104
#     0 windows for fibrillation anomalies ([,!,])
#     10 windows for external anomalies (Q,|)
#     1367 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 208 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/208 -> data-processed/multivariate/MITDB/208.test.csv
# Transforming 209
#   record 209.dat loaded
#   3012/3052 beat annotations for data-raw/MIT-BIH Arrhythmia DB/209 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2481
#     window size = 227
#     window margins (left and right) = 113
#     0 windows for fibrillation anomalies ([,!,])
#     7 windows for external anomalies (Q,|)
#     384 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 209 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/209 -> data-processed/multivariate/MITDB/209.test.csv
# Transforming 210
#   record 210.dat loaded
#   2651/2685 beat annotations for data-raw/MIT-BIH Arrhythmia DB/210 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2226
#     window size = 249
#     window margins (left and right) = 124
#     0 windows for fibrillation anomalies ([,!,])
#     1 windows for external anomalies (Q,|)
#     227 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 210 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/210 -> data-processed/multivariate/MITDB/210.test.csv
# Transforming 212
#   record 212.dat loaded
#   2749/2763 beat annotations for data-raw/MIT-BIH Arrhythmia DB/212 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2746
#     window size = 237
#     window margins (left and right) = 118
#     0 windows for fibrillation anomalies ([,!,])
#     1 windows for external anomalies (Q,|)
#     0 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 212 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/212 -> data-processed/multivariate/MITDB/212.test.csv
# Transforming 213
#   record 213.dat loaded
#   3251/3294 beat annotations for data-raw/MIT-BIH Arrhythmia DB/213 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2051
#     window size = 201
#     window margins (left and right) = 100
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     610 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 213 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/213 -> data-processed/multivariate/MITDB/213.test.csv
# Transforming 214
#   record 214.dat loaded
#   2267/2297 beat annotations for data-raw/MIT-BIH Arrhythmia DB/214 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1753
#     window size = 285
#     window margins (left and right) = 142
#     0 windows for fibrillation anomalies ([,!,])
#     7 windows for external anomalies (Q,|)
#     257 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 214 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/214 -> data-processed/multivariate/MITDB/214.test.csv
# Transforming 215
#   record 215.dat loaded
#   3363/3400 beat annotations for data-raw/MIT-BIH Arrhythmia DB/215 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 3050
#     window size = 193
#     window margins (left and right) = 96
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     168 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 215 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/215 -> data-processed/multivariate/MITDB/215.test.csv
# Transforming 217
#   record 217.dat loaded
#   2209/2280 beat annotations for data-raw/MIT-BIH Arrhythmia DB/217 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1561
#     window size = 301
#     window margins (left and right) = 150
#     0 windows for fibrillation anomalies ([,!,])
#     1 windows for external anomalies (Q,|)
#     422 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 217 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/217 -> data-processed/multivariate/MITDB/217.test.csv
# Transforming 219
#   record 219.dat loaded
#   2287/2312 beat annotations for data-raw/MIT-BIH Arrhythmia DB/219 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1882
#     window size = 287
#     window margins (left and right) = 143
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     72 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
# enter 302003
# for pos 302003 val 302354.0
# enter 303821
# for pos 303821 val 304240.0
# enter 305606
# for pos 305606 val 305959.0
# enter 322204
# for pos 322204 val 322585.0
# enter 323098
# for pos 323098 val 323463.0
# enter 323968
# for pos 323968 val 324327.0
# enter 324800
# for pos 324800 val 325162.0
# enter 325647
# for pos 325647 val 325986.0
# enter 331684
# for pos 331684 val 332045.0
# enter 332528
# for pos 332528 val 332891.0
# enter 333382
# for pos 333382 val 333740.0
# enter 334210
# for pos 334210 val 334558.0
# enter 335042
# for pos 335042 val 335399.0
# enter 335882
# for pos 335882 val 336240.0
# enter 336733
# for pos 336733 val 337076.0
# enter 337562
# for pos 337562 val 337907.0
# enter 338379
# for pos 338379 val 338741.0
# enter 340682
# for pos 340682 val 341058.0
# enter 341542
# for pos 341542 val 341894.0
# enter 342379
# for pos 342379 val 342724.0
# enter 343200
# for pos 343200 val 343543.0
# enter 344038
# for pos 344038 val 344375.0
# enter 344865
# for pos 344865 val 345211.0
# enter 346091
# for pos 346091 val 346442.0
# enter 346931
# for pos 346931 val 347282.0
# enter 347770
# for pos 347770 val 348104.0
# enter 348303
# for pos 348303 val 348665.0
# enter 349145
# for pos 349145 val 349477.0
# enter 349974
# for pos 349974 val 350309.0
# enter 350792
# for pos 350792 val 351140.0
# enter 351346
# for pos 351346 val 351689.0
# enter 352173
# for pos 352173 val 352517.0
# enter 352994
# for pos 352994 val 353346.0
# enter 353544
# for pos 353544 val 353880.0
# enter 354377
# for pos 354377 val 354710.0
# enter 355212
# for pos 355212 val 355541.0
# enter 356033
# for pos 356033 val 356352.0
# enter 356833
# for pos 356833 val 357162.0
# enter 357658
# for pos 357658 val 357995.0
# enter 358493
# for pos 358493 val 358818.0
# enter 359322
# for pos 359322 val 359670.0
# enter 359873
# for pos 359873 val 360198.0
# enter 360403
# for pos 360403 val 360739.0
# enter 360945
# for pos 360945 val 361261.0
# enter 361749
# for pos 361749 val 362073.0
# enter 362568
# for pos 362568 val 362894.0
# enter 363113
# for pos 363113 val 363448.0
# enter 363927
# for pos 363927 val 364257.0
# enter 364464
# for pos 364464 val 364805.0
# enter 365017
# for pos 365017 val 365017
# enter 365563
# for pos 365563 val 365899.0
# enter 366386
# for pos 366386 val 366704.0
# enter 367197
# for pos 367197 val 367518.0
# enter 368020
# for pos 368020 val 368339.0
# enter 368545
# for pos 368545 val 368887.0
# enter 369098
# for pos 369098 val 369427.0
# enter 369642
# for pos 369642 val 369965.0
# enter 370176
# for pos 370176 val 370176
# enter 370716
# for pos 370716 val 371051.0
# enter 371536
# for pos 371536 val 371874.0
# enter 372093
# for pos 372093 val 372409.0
# enter 372621
# for pos 372621 val 372962.0
# enter 373446
# for pos 373446 val 373762.0
# enter 375729
# for pos 375729 val 376086.0
# enter 376303
# for pos 376303 val 376645.0
# enter 376858
# for pos 376858 val 377192.0
# enter 377398
# for pos 377398 val 377584.0
# enter 383575
# for pos 383575 val 383930.0
# enter 386884
# for pos 386884 val 387227.0
# enter 387439
# for pos 387439 val 387790.0
# enter 388001
# for pos 388001 val 388331.0
# enter 389444
# for pos 389444 val 389769.0
# enter 391444
# for pos 391444 val 391794.0
# enter 392010
# for pos 392010 val 392338.0
# enter 392550
# for pos 392550 val 392898.0
# enter 393115
# for pos 393115 val 393436.0
# enter 393645
# for pos 393645 val 393976.0
# enter 394762
# for pos 394762 val 395122.0
# enter 395613
# for pos 395613 val 395930.0
# enter 396434
# for pos 396434 val 396758.0
# enter 397575
# for pos 397575 val 397898.0
# enter 398408
# for pos 398408 val 398727.0
# enter 399829
# for pos 399829 val 400161.0
# enter 400376
# for pos 400376 val 400704.0
# enter 400914
# for pos 400914 val 401248.0
# enter 401463
# for pos 401463 val 401745.0
# enter 417447
# for pos 417447 val 417820.0
# enter 418031
# for pos 418031 val 418379.0
# enter 420433
# for pos 420433 val 420813.0
# enter 421021
# for pos 421021 val 421378.0
# enter 421584
# for pos 421584 val 421926.0
# enter 422136
# for pos 422136 val 422480.0
# enter 422688
# for pos 422688 val 423017.0
# enter 424125
# for pos 424125 val 424454.0
# enter 426494
# for pos 426494 val 426841.0
# enter 427050
# for pos 427050 val 427402.0
# enter 427618
# for pos 427618 val 427948.0
# enter 428159
# for pos 428159 val 428505.0
# enter 428718
# for pos 428718 val 428718
# enter 429261
# for pos 429261 val 429594.0
# enter 432534
# for pos 432534 val 432899.0
# enter 433120
# for pos 433120 val 433474.0
# enter 434611
# for pos 434611 val 434939.0
# enter 436066
# for pos 436066 val 436399.0
# enter 436616
# for pos 436616 val 436966.0
# enter 437182
# for pos 437182 val 437509.0
# enter 437726
# for pos 437726 val 437726
# enter 482061
# for pos 482061 val 482408.0
# enter 482884
# for pos 482884 val 483228.0
# enter 483713
# for pos 483713 val 484068.0
# enter 484552
# for pos 484552 val 484850.0
# enter 485045
# for pos 485045 val 485261.0
# enter 485461
# for pos 485461 val 485835.0
# enter 486326
# for pos 486326 val 486673.0
# enter 487163
# for pos 487163 val 487516.0
# enter 487997
# for pos 487997 val 488351.0
# enter 488840
# for pos 488840 val 489183.0
# enter 489673
# for pos 489673 val 490025.0
# enter 490506
# for pos 490506 val 490845.0
# enter 491343
# for pos 491343 val 491680.0
# enter 492163
# for pos 492163 val 492515.0
# enter 492722
# for pos 492722 val 493074.0
# enter 493566
# for pos 493566 val 493891.0
# enter 494385
# for pos 494385 val 494731.0
# enter 495221
# for pos 495221 val 495554.0
# enter 496051
# for pos 496051 val 496373.0
# enter 496588
# for pos 496588 val 496925.0
# enter 498254
# for pos 498254 val 498612.0
# enter 498824
# for pos 498824 val 499164.0
# enter 499376
# for pos 499376 val 499726.0
# enter 499936
# for pos 499936 val 500274.0
# enter 500483
# for pos 500483 val 500483
# enter 501037
# for pos 501037 val 501037
#     133 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 219 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/219 -> data-processed/multivariate/MITDB/219.test.csv
# Transforming 220
#   record 220.dat loaded
#   2048/2069 beat annotations for data-raw/MIT-BIH Arrhythmia DB/220 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1893
#     window size = 323
#     window margins (left and right) = 161
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     94 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 220 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/220 -> data-processed/multivariate/MITDB/220.test.csv
# Transforming 221
#   record 221.dat loaded
#   2427/2462 beat annotations for data-raw/MIT-BIH Arrhythmia DB/221 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1641
#     window size = 257
#     window margins (left and right) = 128
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     396 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 221 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/221 -> data-processed/multivariate/MITDB/221.test.csv
# Transforming 222
#   record 222.dat loaded
#   2483/2634 beat annotations for data-raw/MIT-BIH Arrhythmia DB/222 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1896
#     window size = 271
#     window margins (left and right) = 135
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     421 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 222 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/222 -> data-processed/multivariate/MITDB/222.test.csv
# Transforming 223
#   record 223.dat loaded
#   2605/2643 beat annotations for data-raw/MIT-BIH Arrhythmia DB/223 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1684
#     window size = 253
#     window margins (left and right) = 126
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     576 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 223 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/223 -> data-processed/multivariate/MITDB/223.test.csv
# Transforming 228
#   record 228.dat loaded
#   2077/2141 beat annotations for data-raw/MIT-BIH Arrhythmia DB/228 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1310
#     window size = 315
#     window margins (left and right) = 157
#     0 windows for fibrillation anomalies ([,!,])
#     24 windows for external anomalies (Q,|)
#     365 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 228 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/228 -> data-processed/multivariate/MITDB/228.test.csv
# Transforming 230
#   record 230.dat loaded
#   2257/2466 beat annotations for data-raw/MIT-BIH Arrhythmia DB/230 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2252
#     window size = 287
#     window margins (left and right) = 143
#     0 windows for fibrillation anomalies ([,!,])
#     1 windows for external anomalies (Q,|)
#     1 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 230 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/230 -> data-processed/multivariate/MITDB/230.test.csv
# Transforming 231
#   record 231.dat loaded
#   1573/2011 beat annotations for data-raw/MIT-BIH Arrhythmia DB/231 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1565
#     window size = 353
#     window margins (left and right) = 176
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     3 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
# enter 52315
# for pos 52315 val 52422.0
# enter 53176
# for pos 53176 val 53176
#     2 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 231 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/231 -> data-processed/multivariate/MITDB/231.test.csv
# Transforming 232
#   record 232.dat loaded
#   1780/1816 beat annotations for data-raw/MIT-BIH Arrhythmia DB/232 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 121
#     window size = 505
#     window margins (left and right) = 252
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     1383 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 232 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/232 -> data-processed/multivariate/MITDB/232.test.csv
# Transforming 233
#   record 233.dat loaded
#   3081/3152 beat annotations for data-raw/MIT-BIH Arrhythmia DB/233 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 1454
#     window size = 213
#     window margins (left and right) = 106
#     0 windows for fibrillation anomalies ([,!,])
#     2 windows for external anomalies (Q,|)
#     849 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 233 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/233 -> data-processed/multivariate/MITDB/233.test.csv
# Transforming 234
#   record 234.dat loaded
#   2753/2764 beat annotations for data-raw/MIT-BIH Arrhythmia DB/234 loaded (others were ignored)
#   preparing windows for labeling...
#     normal beat distance samples = 2695
#     window size = 237
#     window margins (left and right) = 118
#     0 windows for fibrillation anomalies ([,!,])
#     0 windows for external anomalies (Q,|)
#     53 windows for anomalous beats (F,f,S,A,a,V,J,j,E,e)
#     0 windows for missing beats (x)
#   ...done.
#   labeling
#   reconstructing timestamps
# Dataset 234 transformed and saved!
# Processed source dataset data-raw/MIT-BIH Arrhythmia DB/234 -> data-processed/multivariate/MITDB/234.test.csv

# %%
dm.refresh()
dm._df
# Out:
#                                train_path  \
# dataset_name   collection_name
# A1Benchmark-6  WebscopeS5             NaN
# A1Benchmark-3  WebscopeS5             NaN
# A1Benchmark-40 WebscopeS5             NaN
# A1Benchmark-20 WebscopeS5             NaN
# A1Benchmark-4  WebscopeS5             NaN
# ...                                   ...
# 230            MITDB                  NaN
# 231            MITDB                  NaN
# 232            MITDB                  NaN
# 233            MITDB                  NaN
# 234            MITDB                  NaN
#
#                                                                         test_path  \
# dataset_name   collection_name
# A1Benchmark-6  WebscopeS5       data-processed/univariate/WebscopeS5/A1Benchma...
# A1Benchmark-3  WebscopeS5       data-processed/univariate/WebscopeS5/A1Benchma...
# A1Benchmark-40 WebscopeS5       data-processed/univariate/WebscopeS5/A1Benchma...
# A1Benchmark-20 WebscopeS5       data-processed/univariate/WebscopeS5/A1Benchma...
# A1Benchmark-4  WebscopeS5       data-processed/univariate/WebscopeS5/A1Benchma...
# ...                                                                           ...
# 230            MITDB               data-processed/multivariate/MITDB/230.test.csv
# 231            MITDB               data-processed/multivariate/MITDB/231.test.csv
# 232            MITDB               data-processed/multivariate/MITDB/232.test.csv
# 233            MITDB               data-processed/multivariate/MITDB/233.test.csv
# 234            MITDB               data-processed/multivariate/MITDB/234.test.csv
#
#                                 type  datetime_index  split_at    train_type  \
# dataset_name   collection_name
# A1Benchmark-6  WebscopeS5       real            True       NaN  unsupervised
# A1Benchmark-3  WebscopeS5       real            True       NaN  unsupervised
# A1Benchmark-40 WebscopeS5       real            True       NaN  unsupervised
# A1Benchmark-20 WebscopeS5       real            True       NaN  unsupervised
# A1Benchmark-4  WebscopeS5       real            True       NaN  unsupervised
# ...                              ...             ...       ...           ...
# 230            MITDB            real            True       NaN  unsupervised
# 231            MITDB            real            True       NaN  unsupervised
# 232            MITDB            real            True       NaN  unsupervised
# 233            MITDB            real            True       NaN  unsupervised
# 234            MITDB            real            True       NaN  unsupervised
#
#                                 train_is_normal    input_type  length
# dataset_name   collection_name
# A1Benchmark-6  WebscopeS5                 False    univariate    1439
# A1Benchmark-3  WebscopeS5                 False    univariate    1461
# A1Benchmark-40 WebscopeS5                 False    univariate    1427
# A1Benchmark-20 WebscopeS5                 False    univariate    1422
# A1Benchmark-4  WebscopeS5                 False    univariate    1423
# ...                                         ...           ...     ...
# 230            MITDB                      False  multivariate  650000
# 231            MITDB                      False  multivariate  650000
# 232            MITDB                      False  multivariate  650000
# 233            MITDB                      False  multivariate  650000
# 234            MITDB                      False  multivariate  650000
#
# [632 rows x 9 columns]

# %% [markdown]
# ## Dataset transformation walk-through

# %%
def print_obj_attr(obj, name="Object"):
    print(name)
    tmp = vars(obj)
    for key in tmp:
        print(key, tmp[key])
    print("")
records = load_dataset_names()

# %% [markdown]
# ### Load and parse dataset

# %%
records.index("219")
# Out:
# 37

# %%
# dataset
record = wfdb.rdrecord(os.path.join(source_folder, records[37]))
#print_obj_attr(record, "Record object")

df_record = pd.DataFrame(record.p_signal, columns=record.sig_name)
df_record
# Out:
#          MLII     V1
# 0      -0.695 -0.955
# 1      -0.695 -0.955
# 2      -0.695 -0.955
# 3      -0.695 -0.955
# 4      -0.695 -0.955
# ...       ...    ...
# 649995 -0.900 -0.570
# 649996 -0.890 -0.565
# 649997 -0.890 -0.555
# 649998 -0.885 -0.550
# 649999 -1.280  0.000
#
# [650000 rows x 2 columns]

# %% [markdown]
# Add timestamp information based on sample interval ($$[fs] = samples/second$$):

# %%
display(Latex(f"Samples per second: $$fs = {record.fs} \\frac{{1}}{{s}}$$"))
display(Markdown(f"This gives a sample interval of {1e+9/record.fs} nanoseconds"))
df_record["timestamp"] = pd.to_datetime(df_record.index.values * 1e+9/record.fs, unit='ns')
df_record
# Out:
# Samples per second: $$fs = 360 \frac{1}{s}$$
# This gives a sample interval of 2777777.777777778 nanoseconds
#          MLII     V1                     timestamp
# 0      -0.695 -0.955 1970-01-01 00:00:00.000000000
# 1      -0.695 -0.955 1970-01-01 00:00:00.002777777
# 2      -0.695 -0.955 1970-01-01 00:00:00.005555555
# 3      -0.695 -0.955 1970-01-01 00:00:00.008333333
# 4      -0.695 -0.955 1970-01-01 00:00:00.011111111
# ...       ...    ...                           ...
# 649995 -0.900 -0.570 1970-01-01 00:30:05.541666666
# 649996 -0.890 -0.565 1970-01-01 00:30:05.544444444
# 649997 -0.890 -0.555 1970-01-01 00:30:05.547222222
# 649998 -0.885 -0.550 1970-01-01 00:30:05.550000000
# 649999 -1.280  0.000 1970-01-01 00:30:05.552777777
#
# [650000 rows x 3 columns]

# %% [markdown]
# ### Load and parse annotations

# %%
# find all annotations
annotations = {}
for r in records:
    atr = wfdb.rdann(os.path.join(source_folder, r), "atr")
    df_annotation = pd.DataFrame(atr.symbol, index=atr.sample, columns=["Label"])
    for an in df_annotation["Label"].unique():
        if an not in annotations:
            annotations[an] = set()
        annotations[an].add(atr.record_name)

for an in annotations:
    annotations[an] = ", ".join(annotations[an])
annotations
# Out:
# {'+': '205, 107, 109, 234, 117, 215, 230, 111, 103, 210, 222, 123, 232, 233, 101, 200, 209, 102, 118, 220, 203, 113, 124, 114, 115, 223, 100, 108, 207, 112, 121, 104, 219, 119, 122, 228, 231, 212, 213, 202, 106, 116, 105, 201, 217, 214, 221, 208',
#  'N': '205, 234, 117, 215, 230, 103, 210, 222, 123, 233, 101, 200, 209, 102, 220, 203, 113, 114, 115, 223, 100, 108, 112, 121, 104, 219, 119, 122, 228, 231, 212, 213, 202, 106, 116, 105, 201, 217, 221, 208',
#  'A': '205, 117, 215, 103, 222, 232, 233, 101, 200, 209, 118, 220, 124, 114, 223, 108, 100, 207, 112, 121, 219, 231, 228, 213, 202, 116, 201',
#  'V': '205, 107, 109, 234, 215, 230, 111, 210, 123, 233, 200, 209, 102, 118, 203, 124, 114, 223, 100, 108, 207, 121, 219, 104, 231, 119, 228, 213, 202, 106, 116, 105, 201, 217, 214, 221, 208',
#  '~': '205, 107, 109, 234, 117, 215, 230, 111, 103, 210, 222, 232, 101, 200, 209, 118, 220, 203, 124, 114, 115, 223, 108, 207, 112, 121, 104, 119, 228, 212, 106, 116, 105, 201, 217, 214, 221, 208',
#  '|': '205, 230, 210, 233, 101, 209, 203, 114, 115, 108, 207, 228, 122, 212, 202, 105, 217, 214, 208',
#  'Q': '203, 105, 101, 214, 104, 208',
#  '/': '104, 217, 102, 107',
#  'f': '104, 217, 102',
#  'x': '201, 108, 219, 231, 118',
#  'F': '213, 203, 202, 205, 124, 210, 114, 109, 223, 233, 201, 108, 214, 200, 219, 208, 215',
#  'j': '222, 124, 232, 201, 108',
#  'L': '111, 214, 109, 207',
#  'a': '213, 203, 113, 202, 210, 223, 201',
#  'J': '222, 124, 114, 201, 234',
#  'R': '212, 124, 232, 207, 231, 118',
#  '[': '207',
#  '!': '207',
#  ']': '207',
#  'E': '210, 207',
#  'S': '208',
#  '"': '214, 219, 231, 228, 215',
#  'e': '223'}

# %% [markdown]
# Annotations
#
# | Annotation | Description |
# | :--------- | :---------- |
# || **Considered normal** |
# | `N` | Normal beat |
# | `/` | Paced beat (normal beat if pacemaker is used) |
# | `L` | Left bundle branch block beat (also normal?) |
# | `R` | Right bundle branch block beat (also normal?)  |
# || **Anomalous beats** (use double-window labeling) |
# | `F` | Fusion of ventricular and normal beat |
# | `f` | Fusion of paced and normal beat |
# | `S` | Supraventricular premature or ectopic beat |
# | `A` | Atrial premature beat |
# | `a` | Aberrated atrial premature beat |
# | `V` | Premature ventricular contraction |
# | `J` | Nodal (junctional) premature beat |
# | `j` | Nodal (junctional) escape beat |
# | `E` | Ventricular escape beat |
# | `e` | Atrial escape beat |
# || **Anomaly from `x` until next beat window start** |
# | `x` | Non-conducted P-wave (blocked APC) (no beat follows annotation) |
# || **Entire section of fibrillation is regarded anomalous** (a single window from `[` to `]`) |
# | `[` | Start of ventricular flutter/fibrillation |
# | `!` | Ventricular flutter wave |
# | `]` | End of ventricular flutter/fibrillation |
# || **External anomalies** (single window labeling) |
# | `Q` | Unclassifiable beat |
# | `\|` | Isolated QRS-like artifact |
# || **Ignored, bc hard to parse and to label** |
# | `+` | Rythm change |
# | `~` | Change in signal quality (usually noise level changes) |
# | `"` | Tape slippage (unknown; variable length) |

# %%
ann_normal = ["N", "/", "L", "R"]
ann_beat = ["F", "f", "S", "A", "a", "V", "J", "j", "E", "e"]
ann_no_beat = ["x"]
ann_fibr_start = "["
ann_fibr_end = "]"
ann_fibr = [ann_fibr_start, "!", ann_fibr_end]
ann_ext = ["Q", "|"]
ann_ignore = ["+", "~", '"']

# %%
atr = wfdb.rdann(os.path.join(source_folder, records[37]), "atr")
#print_obj_attr(atr, "Annotation object")
assert record.fs == atr.fs, "Sample frequency of records and annotations does not match!"

df_annotation = pd.DataFrame(atr.symbol, index=atr.sample, columns=["Label"])
df_annotation = df_annotation.reset_index()
df_annotation.columns = ["position", "label"]
df_annotation.groupby("label").count()
# Out:
#        position
# label
# "             4
# +            21
# A             7
# F             1
# N          2082
# V            64
# x           133

# %% [markdown]
# ### Remove ignored annotations

# %%
df_annotation = df_annotation[~df_annotation["label"].isin(ann_ignore)]
df_annotation = df_annotation.reset_index(drop=True)
df_annotation.groupby("label").count()
# Out:
#        position
# label
# A             7
# F             1
# N          2082
# V            64
# x           133

# %% [markdown]
# ### Calculate beat window
#
# We assume that the normal beats (e.g. annotated with `N`) occur in a regular interval and that the expert annotations (from the dataset) are directly in the middle of a beat window.
# A beat window is a fixed length subsequence of the time series and shows a heart beat in its direct (local) context.
#
# We calculate the beat window length for each dataset based on the median distance between normal beats.
# The index (autoincrementing integers) serves as the measurement unit.
#
# Shifted-by-one self-join and filter out all beat-pairs that contain anomalous beats.
# We want to calculate the beat windows only based on the normal beats.
# We then calculate the distance between two neighboring heart beats:

# %%
df_normal_beat = df_annotation.copy()
df_normal_beat["prev_position"] = df_annotation["position"].shift()
df_normal_beat["prev_label"] = df_annotation["label"].shift()
df_normal_beat = df_normal_beat[(df_normal_beat["label"].isin(ann_normal)) & (df_normal_beat["prev_label"].isin(ann_normal))]
df_normal_beat = df_normal_beat.drop(columns=["label", "prev_label"])
df_normal_beat["length"] = df_normal_beat["position"] - df_normal_beat["prev_position"]
df_normal_beat.describe()
# Out:
#             position  prev_position       length
# count    1882.000000    1882.000000  1882.000000
# mean   316883.447396  316595.247078   288.200319
# std    195191.983575  195189.840359    57.107310
# min       614.000000     300.000000   183.000000
# 25%    147384.500000  147134.750000   255.000000
# 50%    288621.500000  288355.000000   287.000000
# 75%    506221.500000  505967.500000   312.000000
# max    649737.000000  649448.000000  1108.000000

# %% [markdown]
# The median of all normal beat lengths is the beat window size.
# We require the beat window size to be odd.
# This allows us to center the window at the beat annotation.

# %%
normal_beat_length = df_normal_beat["length"].median()
if (normal_beat_length%2) == 0:
    normal_beat_length += 1
beat_window_size = int(normal_beat_length)
beat_window_margin = (beat_window_size - 1)//2
print(f"window size = {beat_window_size}\nwindow margins (left and right) = {beat_window_margin}")
# Out:
# window size = 287
# window margins (left and right) = 143

# %% [markdown]
# ### Calculate anomalous windows
#
# The experts from PhysioNet annotated only the beats itself with a label, but the actual anomaly is also comprised of the beat surroundings.
#
# We assume that anomalous beats (such as `V` or `F`; see table above) require looking at a window around the actual beat as being anomalous.
# External anomalies (such as `|`; see table above) also mark a window around it as anomalous, because those artefacts comprise multiple points.
#
# We completely ignore `~`, `"`, and `+`-annotations that indicate signal quality or rythm changes, because they are not relevant for our analysis.
#
# We automatically label a variable-sized window around an annotated beat as an anomalous subsequence using the following technique:
#
# 1. For anomalous annotations (such as `S`, `V`, or `F` annotations):
#    - Remove `"`, `~`, `+`, `[`, `]`, and `|` annotations
#    - Calculate anomaly window using `beat_window_size` aligned with its center on the beat annotation.
#    - Calculate end of previous beat window _e_ and beginning of next beat window _b_.
#      Use _e_ as beginning and _b_ as end for a second anomaly window.
#    - Mark the union of both anomaly windows' points as anomalous.
# 2. For `|` and `Q` annotations, mark all points of an anomaly window centered on the annotation as anomalous.
# 3. For `[`, `!`, and `]` annotations, mark all points within the region from `[` until `]` as anomalous.
# 4. For `x` annotations, mark the annotated and all following points until the beginning of the next beat window as anomalous.
# 5. Mark all other points as normal.
#
# > **Explain, why we used the combined windows for anomalous beats!!**
# >
# > - pattern/shape of signal may be ok
# > - but we consider distance to other beats also
# > - if too narrow or too far away, it's also anomalous
#
# The figure shows an anomalous beat with its anomaly window (in red) and the windows of its previous and subsequent normal beats (in green).
# We mark all points in the interval $$[min(W_{end}, X_{start}), max(X_{end}, Y_{start})]$$

# %%
name = df_annotation[df_annotation["label"] == ann_fibr_start].iloc[0].name
df_annotation[df_annotation.index >= name]

# %%
# reverse lookup from timestamp to annotation index in df_beat
p = df_record[df_record["timestamp"] == "1970-01-01 00:11:03.000"].index.values[0]
df_annotation[df_annotation["position"] >= p].index[0]
# Out:
# 840

# %%
def plot_window(pos, color="blue", **kvs):
    start = pos - beat_window_margin
    end = pos + beat_window_margin
    plt.axvspan(start, end, color=color, alpha=0.5, **kvs)


index = 39

beat_n = df_annotation.loc[index, "position"]
print("Selected beat is annotated as", df_annotation.loc[index, "label"])
print("with timestamp", df_record.loc[beat_n, "timestamp"])
ax = df_record.iloc[beat_n-1000:beat_n+1000].plot(kind='line', y=["MLII", "V1"], use_index=True, figsize=(20,10))
plot_window(df_annotation.loc[index-1, "position"], label="$W$")
plot_window(beat_n, color="orange", label="$X$")
plot_window(df_annotation.loc[index+1, "position"], label="$Y$")

labels = df_annotation[(df_annotation["position"] > beat_n-1000) & (df_annotation["position"] < beat_n+1000)]
for i, (position, label) in labels.iterrows():
    plt.text(position, -1.2, label)
plt.legend()
plt.show()
# Out:
# Selected beat is annotated as N
# with timestamp 1970-01-01 00:00:32.797222222

# %% [markdown]
# #### Windows for fibrillation

# %%
# we only need start and end marked with `[` and `]` respectively
s_fibr_start = df_annotation.loc[df_annotation["label"] == ann_fibr_start, "position"]
s_index = s_fibr_start.index
s_fibr_start = s_fibr_start.reset_index(drop=True)

s_fibr_end = df_annotation.loc[df_annotation["label"] == ann_fibr_end, "position"]
s_fibr_end = s_fibr_end.reset_index(drop=True)

df_fibr = pd.DataFrame({"index": s_index, "window_start": s_fibr_start, "window_end": s_fibr_end})
df_fibr = df_fibr.set_index("index")
df_fibr["position"] = df_fibr["window_start"]
df_fibr
# Out:
# Empty DataFrame
# Columns: [window_start, window_end, position]
# Index: []

# %% [markdown]
# #### Windows for external anomalies

# %%
df_ext = df_annotation[df_annotation["label"].isin(ann_ext)].copy()
df_ext["window_start"] = df_ext["position"]-beat_window_margin
df_ext["window_end"] = df_ext["position"]+beat_window_margin
df_ext = df_ext[["position", "window_start", "window_end"]]
df_ext.head()
# Out:
# Empty DataFrame
# Columns: [position, window_start, window_end]
# Index: []

# %% [markdown]
# #### Windows for anomalous beats

# %%
# exclude additional non-beat annotations
df_tmp = df_annotation[~df_annotation["label"].isin(["|", ann_fibr_start, ann_fibr_end])].copy()
df_tmp["position_next"] = df_tmp["position"].shift(-1)
df_tmp["position_prev"] = df_tmp["position"].shift(1)
#df_tmp = df_tmp[(df_tmp["position_prev"].notnull()) & (df_tmp["position_next"].notnull())]
df_tmp = df_tmp[df_tmp["label"].isin(ann_beat)]
df_tmp["window_start"] = np.minimum(df_tmp["position"].values-beat_window_margin, df_tmp["position_prev"].values+beat_window_margin)
df_tmp["window_end"] = np.maximum(df_tmp["position"].values+beat_window_margin, df_tmp["position_next"].values-beat_window_margin)
df_svf = df_tmp[["position", "window_start", "window_end"]]
df_tmp.groupby("label").count()
# Out:
#        position  position_next  position_prev  window_start  window_end
# label
# A             7              7              7             7           7
# F             1              1              1             1           1
# V            64             64             64            64          64

# %% [markdown]
# #### Windows for missing beats (such as `x` annotation)

# %%
df_normal_windows = df_annotation[df_annotation["label"].isin(ann_normal)].copy()
df_normal_windows = df_normal_windows.drop(columns=["label"])
df_normal_windows["window_start"] = df_normal_windows["position"]-beat_window_margin
df_normal_windows["window_end"] = df_normal_windows["position"]+beat_window_margin

df_lut = df_annotation[~df_annotation["label"].isin(ann_no_beat)].merge(pd.concat([df_ext, df_svf, df_fibr, df_normal_windows]), on="position", how="left")
df_lut
# Out:
#       position label  window_start  window_end
# 0          300     N         157.0       443.0
# 1          614     N         471.0       757.0
# 2          887     N         744.0      1030.0
# 3         1206     N        1063.0      1349.0
# 4         1417     N        1274.0      1560.0
# ...        ...   ...           ...         ...
# 2149    648690     N      648547.0    648833.0
# 2150    648836     V      648693.0    649031.0
# 2151    649174     N      649031.0    649317.0
# 2152    649448     N      649305.0    649591.0
# 2153    649737     N      649594.0    649880.0
#
# [2154 rows x 4 columns]

# %%
def find_next_window_start(pos: int):
    next_window_start = df_lut.loc[df_lut["position"] > pos, "window_start"].iloc[0]
    return max(pos, next_window_start)

df_no_beat = df_annotation[df_annotation["label"].isin(ann_no_beat)].drop(columns=["label"]).copy()
df_no_beat["window_start"] = df_no_beat["position"]
df_no_beat["window_end"] = df_no_beat["position"].transform(find_next_window_start)
df_no_beat.head()
# Out:
#       position  window_start  window_end
# 1060    302003        302003    302354.0
# 1066    303821        303821    304240.0
# 1072    305606        305606    305959.0
# 1132    322204        322204    322585.0
# 1135    323098        323098    323463.0

# %% [markdown]
# #### Merge everything together

# %%
df_windows = pd.concat([df_ext, df_svf, df_fibr, df_no_beat])
df_windows.sort_index(inplace=True)
df_windows
# Out:
#       position  window_start  window_end
# 46       13863       13720.0     14006.0
# 84       24435       24292.0     24605.0
# 96       27694       27551.0     27844.0
# 99       28516       28373.0     28659.0
# 116      33245       33102.0     33424.0
# ...        ...           ...         ...
# 2185    620762      620619.0    620927.0
# 2204    625917      625774.0    626080.0
# 2212    628197      628054.0    628433.0
# 2274    646270      646127.0    646417.0
# 2283    648836      648693.0    649031.0
#
# [205 rows x 3 columns]

# %%
index = 798

beat = df_windows.loc[index, "position"]
start = df_windows.loc[index, "window_start"]
end = df_windows.loc[index, "window_end"]
print("Selected beat is annotated as", df_beat.loc[index, "label"])
print("with timestamp", df_record.loc[beat, "timestamp"])
ax = df_record.iloc[beat-500:beat+500].plot(kind='line', y=['ECG1', 'ECG2'], use_index=True, figsize=(20,10))
plt.axvspan(beat-500, start-1, color="green", alpha=0.5, label="normal region 1", ymin=.5)
plt.axvspan(start, end, color="red", alpha=0.5, label="anomalous region", ymin=.5)
plt.axvspan(end+1, beat+500, color="green", alpha=0.5, label="normal region 2", ymin=.5)
plot_window(df_beat.loc[index-1, "position"], label="$W$", ymax=.5)
plot_window(beat_n, color="orange", label="$X$", ymax=.5)
plot_window(df_beat.loc[index+1, "position"], label="$Y$", ymax=.5)
plt.legend()
plt.show()

# %% [markdown]
# ### Add labels

# %%
df = df_record.copy()
df["is_anomaly"] = 0

for _, (_, t1, t2) in df_windows.iterrows():
    tmp = df[df.index >= t1]
    tmp = tmp[tmp.index <= t2]
    df["is_anomaly"].values[tmp.index] = 1

#df = df.set_index("timestamp")
df[df["is_anomaly"] == 1]
# Out:
#          MLII     V1                     timestamp  is_anomaly
# 13720  -0.970 -0.970 1970-01-01 00:00:38.111111111           1
# 13721  -0.930 -0.950 1970-01-01 00:00:38.113888888           1
# 13722  -0.895 -0.925 1970-01-01 00:00:38.116666666           1
# 13723  -0.850 -0.915 1970-01-01 00:00:38.119444444           1
# 13724  -0.830 -0.910 1970-01-01 00:00:38.122222222           1
# ...       ...    ...                           ...         ...
# 649027 -0.740 -0.390 1970-01-01 00:30:02.852777777           1
# 649028 -0.745 -0.385 1970-01-01 00:30:02.855555555           1
# 649029 -0.765 -0.415 1970-01-01 00:30:02.858333333           1
# 649030 -0.780 -0.405 1970-01-01 00:30:02.861111111           1
# 649031 -0.785 -0.420 1970-01-01 00:30:02.863888888           1
#
# [66682 rows x 4 columns]

# %%
index = 370176
snippet_size = 1500

start = max(0, index - snippet_size//2)
end = min(len(df), index + snippet_size//2)
df_show = df.loc[start:end]
df_show.plot(kind='line', y=["MLII", "V1", "is_anomaly"], use_index=True, figsize=(20,10))

labels = df_annotation[(df_annotation["position"] >= start) & (df_annotation["position"] <= end)]
for i, (position, label) in labels.iterrows():
    plt.text(position, -2, label)
plt.legend()
plt.show()

# %% [markdown]
# ## Experimentation

# %%
df = pd.merge(df_record, df_annotation, left_index=True, right_index=True, how="outer")
#df = df.fillna(value={"Label": ".", "is_anomaly": 0})
df.groupby(["is_anomaly"]).count()

# %%
df[df["Label"].notna()]

# %%
import matplotlib.pyplot as plt
df_show = df.loc[27000:28000]
df_show.plot(kind='line', y=['ECG1', 'ECG2', 'is_anomaly'], use_index=True, figsize=(20,10))
plt.show()

# %%
df = pd.read_csv(os.path.join(dataset_subfolder, "800.test.csv"), index_col="timestamp")
df.loc["1970-01-01 00:21:20":"1970-01-01 00:21:40"].plot(figsize=(20,10))
plt.show()
